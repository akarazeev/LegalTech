# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_excel('FilteredViewTransactionsExpensesAll_CSILakiMIesNet_SQL2012 21.11.17.xlsx', sheetname='Sheet2')

# %%
data.head()
# Out:
#   Parent Company / Emoyhtiö Parent Company Type / Emoyhtiön tyyppi  \
# 0                       NaN                                    NaN
# 1                       NaN                                    NaN
# 2                       NaN                                    NaN
# 3                       NaN                                    NaN
# 4                       NaN                                    NaN
#
#   Parent Company Home Country / Emoyhtiön kotimaa  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   Parent Company Industry / Emoyhtiön toimiala  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# ...

# %%
data[data['Author / Tekijä'] == ]
# Out:
# 0        170.00
# 1         85.00
# 2        340.00
# 3        595.00
# 4        850.00
# 5        255.00
# 6        680.00
# 7        850.00
# 8         42.50
# 9        850.00
# 10       595.00
# 11       510.00
# 12        85.00
# 13       425.00
# 14      1105.00
# 15        30.00
# 16       510.00
# 17       170.00
# 18       595.00
# 19      1275.00
# 20       765.00
# 21       510.00
# 22        85.00
# 23       340.00
# 24       595.00
# 25        42.50
# 26       510.00
# 27        42.50
# 28       680.00
# 29       600.00
#          ...
# 5207      64.24
# 5208       0.00
# 5209       0.00
# 5210      63.36
# 5211     180.00
# 5212      10.50
# 5213      37.12
# 5214      24.50
# 5215      86.63
# 5216       0.00
# 5217      10.00
# 5218       0.00
# 5219      10.00
# 5220     194.83
# 5221      47.92
# 5222      48.36
# 5223      -3.46
# 5224      80.61
# 5225       7.17
# 5226      80.61
# 5227     -80.61
# 5228     162.90
# 5229      38.38
# 5230       1.12
# ...

# %%
from openpyxl import load_workbook

# %%
wb = load_workbook(filename='FilteredViewTransactionsExpensesAll_CSILakiMIesNet_SQL2012 21.11.17.xlsx')
